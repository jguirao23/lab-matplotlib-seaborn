# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import math


import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
plt.plot(x,y, color='green')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
plt.plot(x,z, color='blue')
plt.xlabel('x')
plt.ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2

# Plot 1
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('x, y')

# Plot 2
plt.subplot(1, 2, 2)
plt.plot(x,z)
plt.xlabel('x')
plt.ylabel('z')
plt.title('x, z')

plt.tight_layout() # with this method the padding between both graphs is automatically adjusted
plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax[0].plot(x, y, 'b-')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[1].plot(x, z, 'r-')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')

ax[0].set_title('x, y')
ax[1].set_title('x, z')

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
x = np.arange(0,100)
y = x**2
z = np.exp(x)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))
ax[0].plot(x, y, 'b-')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
ax[1].plot(x, z, 'r-')
ax[1].set_xlabel('x')
ax[1].set_ylabel('z')

ax[0].set_title('x, y')
ax[1].set_title('x, z')


plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(20, 10))
ax.plot(x, y, z, 'b-')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('/Users/JAVIER/Ironhack/Ironhack_labs/lab-matplotlib-seaborn/your-code/Fitbit2.csv')
fitbit.sample(10)
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 214  2015-12-08            3801  15884     11.83       2             962.00
# 335  2016-04-06            4112  23286     17.84      19             561.00
# 191  2015-11-15            2853   9499      7.06       2             738.00
# 229  2015-12-23            1789      0      0.00       0               1.44
# 288  2016-02-19            2815  11971      9.23      11             865.00
# 236  2015-12-30             305  12154      9.05       9             617.00
# 305  2016-03-07             322  16699     13.40      11             791.00
# 235  2015-12-29            3135   1226      9.11      11             636.00
# 242  2016-01-05            3241  12127      9.13      16             682.00
# 297  2016-02-28            2844   9504      7.15       2             687.00
#
#      Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

# MEDIAN STEPS BY MONTH_ENCODED
median_steps_month = fitbit.groupby('Months_encoded').agg({'Steps':'median'}).reset_index()

# MEDIAN STEPS BY WORK_OR_WEEKEND
median_steps_week = fitbit.groupby('Work_or_Weekend').agg({'Steps':'median'}).reset_index()

ax[0].bar(median_steps_month['Months_encoded'], median_steps_month['Steps'])
plt.xticks(fontsize=10, rotation=0)
plt.yticks(fontsize=10, rotation=0)
ax[1].bar(median_steps_week['Work_or_Weekend'], median_steps_week['Steps'])

plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10, rotation=0)

plt.savefig('/Users/JAVIER/Ironhack/Ironhack_labs/lab-matplotlib-seaborn/your-code/Figures/figure_1.png')
plt.show()

# %%
"""
The most active months in terms of median steps are April and June, while the least active are October
and December. There is not a material difference between steps during workdays and weekends.
"""
# Out:
# '\nThe most active months in terms of median steps are April and June, while the least active are October\nand December. There is not a material difference between steps during workdays and weekends.\n'

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
x = [fitbit['Steps'], fitbit['Steps'], fitbit['Steps']]
y = [fitbit['Minutes Lightly Active'], fitbit['Minutes Very Active'], fitbit['Minutes Sedentary']]

# %%
for item in range(len(y)):
    plt.scatter(x[item], y[item])
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('/Users/JAVIER/Ironhack/Ironhack_labs/lab-matplotlib-seaborn/your-code/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
titanic.select_dtypes(exclude='object')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.style.available # We look for the styles available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (25,10))
ax[0].hist(titanic['Age'], bins=10)
ax[1].hist(titanic['Age'], bins=20)
ax[2].hist(titanic['Age'], bins=50)
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
Using a lower bin size gives the impression of having a normal distribution, when the reality may be different.
By grouping the values in less bins we lose details.
"""
# Out:
# '\nUsing a lower bin size gives the impression of having a normal distribution, when the reality may be different.\nBy grouping the values in less bins we lose details.\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.hist(titanic['Gender'])
plt.show()

# %%
# Method 2 - seaborn
sns.histplot(titanic['Gender'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.histplot(titanic['Pclass'])
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
plt.style.use('seaborn-v0_8')
plt.boxplot(titanic['Age'], vert=False)
plt.show()

# %%
"""
Using a boxplot let us know certain statistics about our set, such as the median (almost 30 years), the first 
and third quartiles (25% and 75% of the set values are below that level, respectively), the minimum and maximum
values (0, 80) and the outliers (ages from 60 aprox. onwards)
"""
# Out:
# '\nUsing a boxplot let us know certain statistics about our set, such as the median (almost 30 years), the first \nand third quartiles (25% and 75% of the set values are below that level, respectively), the minimum and maximum\nvalues (0, 80) and the outliers (ages from 60 aprox. onwards)\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
The median age of the set is a bit lower than 30, and more than 75% of the ages are below 40 years.
The maximum age is 80 and the minimum is 1.
"""
# Out:
# '\nThe median age of the set is a bit lower than 30, and more than 75% of the ages are below 40 years.\nThe maximum age is 80 and the minimum is 1.\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
plt.hist(titanic['Age'])
plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Most values are comprised between 20 and 40 years.
"""
# Out:
# '\nMost values are comprised between 20 and 40 years.\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
plt.scatter(titanic['Age'], titanic['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.xlim([0, 85])
plt.ylim([0, 600])
plt.show()

# %%
# Method 2 - seaborn
sns.scatterplot(x=titanic['Age'], y=titanic['Fare'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.xlim([0, 85])
plt.ylim([0, 600])
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
plt.style.use('default')
titanic_corr = titanic.corr(numeric_only=True)
titanic_corr.style.background_gradient(cmap='RdYlGn').format('{:,.2f}')
# Out:
# <style type="text/css">
# #T_e9ae1_row0_col0, #T_e9ae1_row1_col1, #T_e9ae1_row2_col2, #T_e9ae1_row3_col3, #T_e9ae1_row4_col4, #T_e9ae1_row5_col5, #T_e9ae1_row6_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e9ae1_row0_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_e9ae1_row0_col2, #T_e9ae1_row6_col4 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_e9ae1_row0_col3 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_e9ae1_row0_col4 {
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_e9ae1_row0_col5 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_e9ae1_row0_col6 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_e9ae1_row1_col0 {
#   background-color: #bd1726;
#   color: #f1f1f1;
# }
# #T_e9ae1_row1_col2, #T_e9ae1_row2_col5 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_e9ae1_row1_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_e9ae1_row1_col4 {
# ...

# %%
mask = np.zeros_like(titanic_corr)
mask[np.triu_indices_from(mask)] = True

# Plot heatmap
sns.heatmap(titanic_corr, mask=mask, annot=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
We do not find very strong correlations among the variables in the dataset. 
The strongest correlations are Fare-Pclass and Age-Pclass. They seem to have a negative correlation, but if 
we look closer at the Pclass, it takes values between 1 and 3. It seems that the higher class is the one 
represented by value 1 instead of 3, so it would mean that when the class is higher (lowest Pclass), the Fare is 
higher too. The same would happen between Age-Pclass.
"""
# Out:
# '\nWe do not find very strong correlations among the variables in the dataset. \nThe strongest correlations are Fare-Pclass and Age-Pclass. They seem to have a negative correlation, but if \nwe look closer at the Pclass, it takes values between 1 and 3. It seems that the higher class is the one \nrepresented by value 1 instead of 3, so it would mean that when the class is higher (lowest Pclass), the Fare is \nhigher too. The same would happen between Age-Pclass.\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
g = sns.FacetGrid(titanic, col='Pclass')
g.map(sns.histplot, 'Age')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col='Gender')
g.map(sns.histplot, 'Age')
